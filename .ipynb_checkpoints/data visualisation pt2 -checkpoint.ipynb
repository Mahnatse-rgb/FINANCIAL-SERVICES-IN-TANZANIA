# %% [markdown]
# # FINANCIAL SERVICES USE IN TANZANIA
#
# ## Background
#
# The  dataset contains demographic information and what financial services are used by approximately 10,000 individuals across Tanzania. This data was extracted from the FSDT Finscope 2017 survey.
#
# ### Each individual is classified into four mutually exclusive categories:
#
# 1. No_financial_services: Individuals who do not use mobile money, do not save, do not have credit, and do not have insurance
#
# 2. Other_only: Individuals who do not use mobile money, but do use at least one of the other financial services (savings, credit, insurance)
#
# 3. Mm_only: Individuals who use mobile money only
#
# 4. Mm_plus: Individuals who use mobile money and also use at least one of the other financial services (savings, credit, insurance)
#
# This dataset is the geospatial mapping of all cash outlets in Tanzania in 2012. Cash outlets in this case included commercial banks, community banks, ATMs, microfinance institutions, mobile money agents, bus stations and post offices. This data was collected by FSDT.

# %%
#loading all neccessary python modules and files to use

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

train = pd.read_csv("/home/recruit/Downloads/umuzi/projects/Data Visualisation 2/training.csv")

# %% [markdown]
# ## 1. Examining the dataset

# %%
#Display the contents of the training csv file

print(train)
# Out:
#         ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q17  Q18  Q19  \
# 0     5086  98   2   3   1   1   2   2     0     0  ...   -1    4    4
# 1     1258  40   1   1   3   5   1   1     1     0  ...    4    1    4
# 2      331  18   2   4   6   3   2   1     0     0  ...   -1    1    1
# 3     6729  50   1   1   3   1   1   1     0     0  ...   -1    1    4
# 4     8671  34   1   1   1   1   2   1     0     1  ...   -1    1    4
# ...    ...  ..  ..  ..  ..  ..  ..  ..   ...   ...  ...  ...  ...  ...
# 7089  8378  57   2   3   3   1   2   2     0     1  ...   -1    1    4
# 7090   881  32   1   1   6   3   1   1     0     1  ...   -1    1    1
# 7091  6672  22   2   3   3   3   2   2     0     1  ...   -1    4    4
# 7092  5416  28   2   1   3   1   2   2     0     1  ...   -1    1    4
# 7093  3946  78   1   3   1   1   2   2     0     0  ...   -1    4    4
#
#       Latitude  Longitude  mobile_money  savings  borrowing  insurance  \
# ...

# %%
#Examine the dataset for misssing values and other unvalid information

train.isnull().sum()
# Out:
# ID                             0
# Q1                             0
# Q2                             0
# Q3                             0
# Q4                             0
# Q5                             0
# Q6                             0
# Q7                             0
# Q8_1                           0
# Q8_2                           0
# Q8_3                           0
# Q8_4                           0
# Q8_5                           0
# Q8_6                           0
# Q8_7                           0
# Q8_8                           0
# Q8_9                           0
# Q8_10                          0
# Q8_11                          0
# Q9                             0
# Q10                            0
# Q11                            0
# Q12                            0
# Q13                            0
# Q14                            0
# Q15                            0
# Q16                            0
# Q17                            0
# ...

# %% [markdown]
# There are no missing values in this data set, it looks clean

# %% [markdown]
# ## 2. Basic descriptive statistics of dataset

# %%
#Getting basic descriptive statistics of the dataset.
train.describe()
# Out:
#                 ID           Q1           Q2           Q3           Q4  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000
# mean   4742.627291    38.239498     1.559910     1.787426     3.060051
# std    2731.120086    16.332148     0.496433     1.165160     1.557779
# min       1.000000    16.000000     1.000000     1.000000     1.000000
# 25%    2397.250000    25.000000     1.000000     1.000000     2.000000
# 50%    4744.500000    35.000000     2.000000     1.000000     3.000000
# 75%    7105.000000    48.000000     2.000000     3.000000     3.000000
# max    9459.000000   100.000000     2.000000     4.000000     8.000000
#
#                 Q5           Q6           Q7         Q8_1         Q8_2  ...  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000  ...
# mean      2.548915     1.840569     1.397942     0.062165     0.630110  ...
# std       1.534257     0.366103     0.489508     0.241472     0.482809  ...
# ...

# %%
#Renaming Columns for ease of use

train = train.rename(columns={'Q1':'age', 'Q2':'gender', 'Q3':'marital_status', 'Q6':'land_owned', 'Q8_1':'wage_income'})
train = train.rename(columns={'Q8_2':'trade_income', 'Q8_3':'service_income', 'Q8_4':'piece_income', 'Q8_5':'rent_income', 'Q8_6':'interest_income'})
train = train.rename(columns={'Q8_7':'pension_income', 'Q8_8':'welfare_income', 'Q8_9':'dependant_income', 'Q8_10':'expansepaid_income', 'Q8_11':'other_income'})

#Encoding the mobile_money_classification column
train['mobile_money_classification'] = train['mobile_money_classification'].astype(str)
new_mm_classification = {'mobile_money_classification': {'0':'no_financial_services', '1':'other_only', '2':'mm_only', '3':'mm_plus'}}
train.replace(new_mm_classification, inplace=True)

#Display changes

train.head()
# Out:
#      ID  age  gender  marital_status  Q4  Q5  land_owned  Q7  wage_income  \
# 0  5086   98       2               3   1   1           2   2            0
# 1  1258   40       1               1   3   5           1   1            1
# 2   331   18       2               4   6   3           2   1            0
# 3  6729   50       1               1   3   1           1   1            0
# 4  8671   34       1               1   1   1           2   1            0
#
#    trade_income  ...  Q17  Q18  Q19  Latitude  Longitude  mobile_money  \
# 0             0  ...   -1    4    4 -4.460442  29.811396             0
# 1             0  ...    4    1    4 -6.176438  39.244871             1
# 2             0  ...   -1    1    1 -6.825702  37.652798             1
# 3             0  ...   -1    1    4 -3.372049  35.808307             1
# 4             1  ...   -1    1    4 -7.179645  31.039095             1
#
#    savings  borrowing  insurance  mobile_money_classification
# ...

# %% [markdown]
# ## 3. Visual repressentation of the relationships occuring in the data

# %% [markdown]
# #### 3.1 Financial Services Accessed by Age

# %%
#Visual representation of the relationship between accessed financial services (non-mobile, mobile, both) and age.

sns.boxplot(x='mobile_money_classification', y='age', data=train).set_title('Financial Services Accessed by Age')
# Out:
# Text(0.5, 1.0, 'Financial Services Accessed by Age')

# %% [markdown]
# #### 3.2 Accessed Financial Services by Gender

# %%
#Visual representation of the relationship between accessed financial services (non-mobile, mobile, both) and Gender


gender_frequency.plot(kind='bar', stacked=False).set_title('Accessed Financial Services by Gender')
plt.ylabel('frequency')
plt.legend(('male','female'))

# %% [markdown]
# #### 3.3 Financial Services Accessed by Marital Status

# %%
#Visual representation of the relationship between accessed financial services (non-mobile, mobile, both) and Marital Status

marital_status.plot(kind='bar', stacked=False).set_title('Financial Services Accessed by Marital Status')
plt.ylabel('frequency')
plt.legend(('married','divorced', 'widowed' , 'single/never married'))

# %% [markdown]
# #### 3.4 Financial Services Accessed as per Land Owned

# %%
land_ownwership.plot(kind='bar', stacked=False).set_title('Financial Services Accessed as per Land Owned')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %%
land_ownwership = pd.crosstab(index=train['mobile_money_classification'], columns=train['land_owned'])

land_ownwership
# Out:
# land_owned                     1     2
# mobile_money_classification
# mm_only                      105   699
# mm_plus                      647  2479
# no_financial_services        134  1252
# other_only                   245  1533

# %% [markdown]
# ### 3.5 Financial Services Accessed by various Types of Income

# %% [markdown]
# #### 3.5.1 Income recieved from Wages

# %%
wage_income = pd.crosstab(index=train['mobile_money_classification'], columns=train['wage_income'])

wage_income.plot(kind='bar', stacked=False).set_title('Financial Services Accessed per Wage Income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 3.5.2. Income recieved from trading

# %%
trade_income = pd.crosstab(index=train['mobile_money_classification'], columns=train['trade_income'])

trade_income.plot(kind='bar', stacked=False).set_title('Financial Services Accessed by Trade Income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 3.5.3. Income recieved from providing a service

# %%
service_income = pd.crosstab(index=train['mobile_money_classification'], columns=train['service_income'])

service_income.plot(kind='bar', stacked=False).set_title('Financial Services Accessed by Service Income Recievers')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 3.5.4. Income recieved from casual labour

# %%
casual_labour_income = pd.crosstab(index=train['mobile_money_classification'], columns=train['piece_income'])

# plot graph
casual_labour_income.plot(kind='bar', stacked=False).set_title('Financial Services Accessed by Casual Labour Income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 3.5.5. Income recieved from rentals

# %%
rent_income = pd.crosstab(index=train['mobile_money_classification'], columns=train['rent_income'])

# plot graph
rent_income.plot(kind='bar', stacked=False).set_title('Financial Services Accessed by Rental Income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 3.5.6. Income recieved from interest on investments, savings, stocks, unit trusts and etc

# %%
interest_income = pd.crosstab(index=train['mobile_money_classification'], columns=train['interest_income'])

# plot graph
interest_income.plot(kind='bar', stacked=False).set_title('Financial Services Accessed as per Interest Income Earners')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 3.5.7. Income recieved from pension fund

# %%
pension_fund = pd.crosstab(index=train['mobile_money_classification'], columns=train['pension_income'])

# plot graph
pension_fund.plot(kind='bar', stacked=False).set_title('Financial Services Accessed by Pension Fund Recievers')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 3.5.8. Income recieved from social welfare grant

# %%
social_grant = pd.crosstab(index=train['mobile_money_classification'], columns=train['welfare_income'])

# plot graph
social_grant.plot(kind='bar', stacked=False).set_title('Financial Services Accessed by Social Welfare Income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 3.5.9. Income recieved from relying on someone else

# %%
given_money = pd.crosstab(index=train['mobile_money_classification'], columns=train['dependant_income'])

# plot graph
given_money.plot(kind='bar', stacked=False).set_title('Financial Services Accessed by people relying on someone else to give them money')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 3.5.10. No income recieved

# %%
no_income = pd.crosstab(index=train['mobile_money_classification'], columns=train['expansepaid_income'])

# plot graph
no_income.plot(kind='bar', stacked=False).set_title('Financial Services Accessed by people with no income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 3.5.11. Income recieved by other means

# %%
other_income = pd.crosstab(index=train['mobile_money_classification'], columns=train['other_income'])

# plot graph
other_income.plot(kind='bar', stacked=False).set_title('Financial Services Accessed by other income recievers')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# # 4. Graphic Representation

# %%
# Rename column header
train = train.rename(columns={'Q16':'mobile_money_usage'})

# Encoding the mobile_money_usage column
train['mobile_money_usage'] = train['mobile_money_usage'].astype(str)
new_classification = {'mobile_money_usage': {'-1':'no_applicable', '1':'never', '2':'daily', '3':'weekly', '4':'monthly', '5':'less_than_monthly'}}
train.replace(new_classification, inplace=True)

# %% [markdown]
# #### 4.1. Frequency of Mobile Money Usage by Age¶

# %%
sns.boxplot(x='mobile_money_usage', y='age', data=train).set_title('Frequency of Mobile Money Usage by Age')
# Out:
# Text(0.5, 1.0, 'Frequency of Mobile Money Usage by Age')

# %% [markdown]
# #### 4.2. Frequency of Mobile Money Usage as per Marital Status

# %%
marital_state = pd.crosstab(index=train['mobile_money_usage'], columns=train['marital_status'])

# plot graph
marital_state.plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage vs Marital Status')
plt.ylabel('frequency')
plt.legend(('married','divorced', 'widowed' , 'single/never married'))

# %% [markdown]
# #### 4.3. Frequency of Mobile Money Usage by Gender

# %%
gender = pd.crosstab(index=train['mobile_money_usage'], columns=train['gender'])

# plot graph
gender.plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage by Gender')
plt.ylabel('frequency')
plt.legend(('male','female'))

# %% [markdown]
# #### 4.4. Frequency of Mobile Money Usage by Land Ownership

# %%
owned_land = pd.crosstab(index=train['mobile_money_usage'], columns=train['land_owned'])

# plot graph
owned_land.plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage by Land Ownership')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# ## 4.5 Frequency of Mobile Money Usage by Type of Income

# %% [markdown]
# #### 4.5.1 Wage Income

# %%
income_type = pd.crosstab(index=train['mobile_money_usage'], columns=train['wage_income'])

# plot graph
income_type.plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage by Wage Income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 4.5.2 Trading income

# %%
trading_income = pd.crosstab(index=train['mobile_money_usage'], columns=train['trade_income'])

# plot graph
trading_income.plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage by Trade Income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 4.5.3 Income from services

# %%
serv_income = pd.crosstab(index=train['mobile_money_usage'], columns=train['service_income'])

# plot graph
serv_income.plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage by Service Income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 4.5.4 Income form casual labour

# %%
casual_job = pd.crosstab(index=train['mobile_money_usage'], columns=train['piece_income'])

# plot graph
casual_job.plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage by Casual Labour Income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 4..5.5 Rental Income

# %%
rent_income = pd.crosstab(index=train['mobile_money_usage'], columns=train['rent_income'])

# plot graph
rent_income.plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage by Rental Income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 4.5.6 Interest from savings, investments, stocks, unit trusts etc.

# %%
int_income = pd.crosstab(index=train['mobile_money_usage'], columns=train['interest_income'])

# plot graph
int_income.plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage by Interest Income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 4.5.7 Pension Fund Income

# %%
fund_income = pd.crosstab(index=train['mobile_money_usage'], columns=train['pension_income'])

# plot graph
fund_income.plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage by Pension Income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 4.5.8 Social welfare grant

# %%
social_income = pd.crosstab(index=train['mobile_money_usage'], columns=train['welfare_income'])

# plot graph
social_income .plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage by Welfare Income')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 4.5.9 Relying on someone to give money

# %%
givings = pd.crosstab(index=train['mobile_money_usage'], columns=train['dependant_income'])

# plot graph
givings.plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage from being given money')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 4.5.10 Don’t get money – someone else pays my expenses

# %%
non_income = pd.crosstab(index=train['mobile_money_usage'], columns=train['expansepaid_income'])

# plot graph
non_income.plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage by having your Expenses Paid for')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# #### 4.5.11 Other source/s of income

# %%
oth_income = pd.crosstab(index=train['mobile_money_usage'], columns=train['other_income'])

# plot graph
oth_income.plot(kind='bar', stacked=False).set_title('Frequency of Mobile Money Usage by Other Income Receiver')
plt.ylabel('frequency')
plt.legend(('Yes','No'))

# %% [markdown]
# ## 5. Geographic Distribution Representation

# %%
from geopy.geocoders import Nominatim
import folium

lat = -6.3728253 ; lon = 34.8924826
Country_map = folium.Map(location=[lat, lon], zoom_start=6)


for lat, long, label in zip(train['Latitude'],train['Longitude'],'Q8_9'):
    folium.CircleMarker(
        [lat, long],
        radius = 10,
        color = 'green',
        parse_htmtl=False
    ).add_to(Country_map)
Country_map



for lat, long, label in zip(train['Latitude'],train['Longitude'],'Q8_5'):
    folium.CircleMarker(
        [lat, long],
        radius = 5,
        color = 'yellow',
        parse_htmtl=False
    ).add_to(Country_map)
Country_map

for lat, lng, label in zip(train[train.mobile_money == 1].Latitude,
                           train[train.mobile_money == 1].Longitude,
                           str(train.ID)):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.4,
        parse_html=False).add_to(Country_map) 



for lat, long, label in zip(train['Latitude'],train['Longitude'],'Q8_1'):
    folium.CircleMarker(
        [lat, long],
        radius = 10,
        color = 'yellow',
        parse_htmtl=False
    ).add_to(Country_map)
Country_map




for lat, long, label in zip(train['Latitude'],train['Longitude'],'Q8_8'):
    folium.CircleMarker(
        [lat, long],
        radius = 10,
        color = 'yellow',
        parse_htmtl=False
    ).add_to(Country_map)
Country_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 6. Conclusion

# %% [markdown]
# According to the geographic map, there is a larger population of people living within the cities and surrounding areas who are dominating the mobile money services users and other financial services. According to graph 4.3, more males make use of mobile money services than females, however graph  3.2 indicates that females dominate males in using other financial services.
#
# More people ranging in the age of 20 years old to 30 years old access more of mobile money financial services than those above 65 years of age, this is according to graph 3.1.
#
# Married people acccess the mobile money financial services the most, followed by single people who has never gotten married , followed by the people who are divorced and lastly the widowed, this is according to graph 3.3 above.
#
# According to section 3.5, people who recieved their income through casual labour, providing services, interest from investments, penssion fund, social welfare grand are most active in mobile money finanial  services
